# %%
import pandas as pd

# %%
df=pd.read_csv("/content/database.csv")

# %%
df.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0                     NaN        6.0             MW  ...
# 1                     NaN        5.8             MW  ...
# 2                     NaN        6.2             MW  ...
# 3                     NaN        5.8             MW  ...
# 4                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# ...

# %%
df[['Date', 'Time'] ] # This will return the "date" and "time" columns
# Out:
#              Date      Time
# 0      01/02/1965  13:44:18
# 1      01/04/1965  11:29:49
# 2      01/05/1965  18:05:58
# 3      01/08/1965  18:49:43
# 4      01/09/1965  13:32:50
# ...           ...       ...
# 23407  12/28/2016  08:22:12
# 23408  12/28/2016  09:13:47
# 23409  12/28/2016  12:38:51
# 23410  12/29/2016  22:30:19
# 23411  12/30/2016  20:08:28
#
# [23412 rows x 2 columns]

# %%
#fetching date, month,year,hour,minute and second from a date time stamp
#difference between two dates in DAYS,MONTHS & Years
#adding or subtracting Days ,months & years from a date

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23412 entries, 0 to 23411
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        23412 non-null  object
#  1   Time                        23412 non-null  object
#  2   Latitude                    23412 non-null  float64
#  3   Longitude                   23412 non-null  float64
#  4   Type                        23412 non-null  object
#  5   Depth                       23412 non-null  float64
#  6   Depth Error                 4461 non-null   float64
#  7   Depth Seismic Stations      7097 non-null   float64
#  8   Magnitude                   23412 non-null  float64
#  9   Magnitude Type              23409 non-null  object
#  10  Magnitude Error             327 non-null    float64
#  11  Magnitude Seismic Stations  2564 non-null   float64
#  12  Azimuthal Gap               7299 non-null   float64
# ...

# %%
# Convert 'Date' column to datetime format if not already done
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# Now extract only the date part
df['dateOnly'] = df['Date'].dt.date

df['Time'] =pd.to_datetime(df['Time'], errors='coerce')
df['timeOnly'] = df['Time'].dt.time

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23412 entries, 0 to 23411
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        23409 non-null  datetime64[ns]
#  1   Time                        0 non-null      datetime64[ns]
#  2   Latitude                    23412 non-null  float64
#  3   Longitude                   23412 non-null  float64
#  4   Type                        23412 non-null  object
#  5   Depth                       23412 non-null  float64
#  6   Depth Error                 4461 non-null   float64
#  7   Depth Seismic Stations      7097 non-null   float64
#  8   Magnitude                   23412 non-null  float64
#  9   Magnitude Type              23409 non-null  object
#  10  Magnitude Error             327 non-null    float64
#  11  Magnitude Seismic Stations  2564 non-null   float64
# ...

# %%
df['dateOnly']=df.Date.dt.date

# %%
df.head()
# Out:
#         Date Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0 1965-01-02  NaT    19.246    145.616  Earthquake  131.6          NaN
# 1 1965-01-04  NaT     1.863    127.352  Earthquake   80.0          NaN
# 2 1965-01-05  NaT   -20.579   -173.972  Earthquake   20.0          NaN
# 3 1965-01-08  NaT   -59.076    -23.557  Earthquake   15.0          NaN
# 4 1965-01-09  NaT    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  Horizontal Distance  \
# 0                     NaN        6.0             MW  ...                  NaN
# 1                     NaN        5.8             MW  ...                  NaN
# 2                     NaN        6.2             MW  ...                  NaN
# 3                     NaN        5.8             MW  ...                  NaN
# 4                     NaN        5.8             MW  ...                  NaN
#
# ...

# %%
df[['Date', 'Time'] ] # This will return the "date" and "time" columns
# Out:
#             Date Time
# 0     1965-01-02  NaT
# 1     1965-01-04  NaT
# 2     1965-01-05  NaT
# 3     1965-01-08  NaT
# 4     1965-01-09  NaT
# ...          ...  ...
# 23407 2016-12-28  NaT
# 23408 2016-12-28  NaT
# 23409 2016-12-28  NaT
# 23410 2016-12-29  NaT
# 23411 2016-12-30  NaT
#
# [23412 rows x 2 columns]

# %%
df['dateOnly']=df.Date.dt.date
df['timeOnly']=df.Date.dt.time
df.head()
# Out:
#         Date Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0 1965-01-02  NaT    19.246    145.616  Earthquake  131.6          NaN
# 1 1965-01-04  NaT     1.863    127.352  Earthquake   80.0          NaN
# 2 1965-01-05  NaT   -20.579   -173.972  Earthquake   20.0          NaN
# 3 1965-01-08  NaT   -59.076    -23.557  Earthquake   15.0          NaN
# 4 1965-01-09  NaT    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  Horizontal Distance  \
# 0                     NaN        6.0             MW  ...                  NaN
# 1                     NaN        5.8             MW  ...                  NaN
# 2                     NaN        6.2             MW  ...                  NaN
# 3                     NaN        5.8             MW  ...                  NaN
# 4                     NaN        5.8             MW  ...                  NaN
#
# ...
